# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


def loadResult(filePath):
    return pd.read_csv(filePath,
                        header=None,
                        skiprows=2,
                        names=['IdScenary','TotalRepeats','TotalFolds','ExecutionNumber','CurrentRepeatNumber', 'CurrentFoldNumber',
                               'DatabaseName','NumProcessUsed','ElipsedTrainingTime','ElipsedPredict1Time','ElipsedPredict2Time',
                               'ErrorPredict1', 'ErrorPredict2'
                               ])


#creating an empty dataframe
dfResults = pd.DataFrame(columns=['IdScenary','TotalRepeats','TotalFolds','ExecutionNumber','CurrentRepeatNumber', 'CurrentFoldNumber',
                               'DatabaseName','NumProcessUsed','ElipsedTrainingTime','ElipsedPredict1Time','ElipsedPredict2Time',
                               'ErrorPredict1', 'ErrorPredict2'
                               ])

#appending results
#Execucao maquina trabalho
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_0-ElectricalFaultDetection-1-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_1-ElectricalFaultDetection-4-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_2-ElectricalFaultDetection-8-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_3-ElectricalFaultDetection-16-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_4-ElectricalFaultDetection-32-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/Downloads/results/output_5-ElectricalFaultDetection-48-30-10.txt')], ignore_index=True)

#Execucao maquina trabalho 2
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_1-ElectricalFaultDetection-4-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_2-ElectricalFaultDetection-8-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_3-ElectricalFaultDetection-16-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_4-ElectricalFaultDetection-32-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_5-ElectricalFaultDetection-48-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_6-Iris-4-30-0.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_7-Iris-8-30-0.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_8-Iris-16-30-0.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_9-Iris-32-30-0.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('/home/saulo/fsp-parallel/benchmark/output2/output_10-Iris-48-30-0.txt')], ignore_index=True)


#Execucao Laboratorio 
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_1-ElectricalFaultDetection-4-30-10.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_2-ElectricalFaultDetection-8-30-10.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_3-ElectricalFaultDetection-16-30-10.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_4-ElectricalFaultDetection-32-30-10.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_5-Iris-4-30-0.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_6-Iris-8-30-0.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_7-Iris-16-30-0.txt')], ignore_index=True)
dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output/output_8-Iris-32-30-0.txt')], ignore_index=True)

#Execucao confirmacao Laboratorio
# dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output3/output_21-ElectricalFaultDetection-16-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output3/output_22-ElectricalFaultDetection-24-30-10.txt')], ignore_index=True)
# dfResults = pd.concat([dfResults, loadResult('~/fsp-parallel/benchmark/output3/output_23-ElectricalFaultDetection-32-30-10.txt')], ignore_index=True)


#creating categorical to be possible sort dataframe by the amount of observations
dfResults['DatabaseName'] = pd.Categorical(dfResults['DatabaseName'], ["Iris","ElectricalFaultDetection"])
# dfResults['DatabaseName'] = pd.Categorical(dfResults['DatabaseName'], ["ElectricalFaultDetection"])

#creating accuracy columns
dfResults["AccuracyPredict1"] = (1 - dfResults["ErrorPredict1"])*100
dfResults["AccuracyPredict2"] = (1 - dfResults["ErrorPredict2"])*100

#sorting by desired values
dfResults = dfResults.sort_values(by=['DatabaseName', 'NumProcessUsed'])

dfResults
# Out:
#      IdScenary TotalRepeats TotalFolds ExecutionNumber CurrentRepeatNumber  \
# 1200         5           30        150               0                   0
# 1201         5           30        150               1                   0
# 1202         5           30        150               2                   0
# 1203         5           30        150               3                   0
# 1204         5           30        150               4                   0
# ...        ...          ...        ...             ...                 ...
# 1195         4           30         10             295                  29
# 1196         4           30         10             296                  29
# 1197         4           30         10             297                  29
# 1198         4           30         10             298                  29
# 1199         4           30         10             299                  29
#
#      CurrentFoldNumber              DatabaseName NumProcessUsed  \
# ...

# %%
dfStatistics = dfResults.describe()

dfStatistics
# Out:
#        ElipsedTrainingTime  ElipsedPredict1Time  ElipsedPredict2Time  \
# count         19200.000000         19200.000000         19200.000000
# mean              0.162984             0.000246             0.023312
# std               0.581792             0.000211             0.090043
# min               0.003706             0.000165             0.000056
# 25%               0.012677             0.000182             0.000066
# 50%               0.016389             0.000187             0.000145
# 75%               0.021426             0.000212             0.000236
# max               3.980138             0.002459             0.467127
#
#        ErrorPredict1  ErrorPredict2  AccuracyPredict1  AccuracyPredict2
# count   19200.000000   19200.000000      19200.000000      19200.000000
# mean        0.060973       0.053208         93.902726         94.679209
# std         0.238242       0.223578         23.824181         22.357802
# ...

# %%
groupedByDatabaseProcessRepeat = dfResults.groupby(
                                ['DatabaseName','NumProcessUsed', 'CurrentRepeatNumber']
                              ).agg(
                                     ElipsedTimeTraining=('ElipsedTrainingTime','sum'),
                                     ElipsedTimePredict1=('ElipsedPredict1Time','sum'),
                                     ElipsedTimePredict2=('ElipsedPredict2Time','sum'),
                                     AccuracyPredict1=('AccuracyPredict1','mean'),
                                     AccuracyPredict2=('AccuracyPredict2','mean')
                                    )

groupedByDatabaseProcessRepeat
# Out:
#                                                              ElipsedTimeTraining  \
# DatabaseName             NumProcessUsed CurrentRepeatNumber
# Iris                     4              0                               2.304235
#                                         1                               2.276364
#                                         2                               2.271912
#                                         3                               2.363087
#                                         4                               2.311489
# ...                                                                          ...
# ElectricalFaultDetection 32             25                             21.060308
#                                         26                             19.999288
#                                         27                             20.382068
#                                         28                             19.684564
# ...

# %%
sumarizedByDatabaseProcessRepeat = groupedByDatabaseProcessRepeat.reset_index()

sumarizedByDatabaseProcessRepeat
# Out:
#                  DatabaseName  NumProcessUsed  CurrentRepeatNumber  \
# 0                        Iris               4                    0
# 1                        Iris               4                    1
# 2                        Iris               4                    2
# 3                        Iris               4                    3
# 4                        Iris               4                    4
# ..                        ...             ...                  ...
# 235  ElectricalFaultDetection              32                   25
# 236  ElectricalFaultDetection              32                   26
# 237  ElectricalFaultDetection              32                   27
# 238  ElectricalFaultDetection              32                   28
# 239  ElectricalFaultDetection              32                   29
#
#      ElipsedTimeTraining  ElipsedTimePredict1  ElipsedTimePredict2  \
# 0               2.304235             0.028594             0.021442
# ...

# %%
#create table with all data sumarized

sumarizedGroup = sumarizedByDatabaseProcessRepeat.groupby(
                                ['DatabaseName','NumProcessUsed']
                                ).agg({
    'ElipsedTimeTraining': [('Mean', 'mean'),('Std', 'std')],  # Subcolunas dentro de 'Valor1'
    'ElipsedTimePredict1': [('Mean', 'mean'),('Std', 'std')],  # Subcolunas dentro de 'Valor1'
    'ElipsedTimePredict2': [('Mean', 'mean'),('Std', 'std')],  # Subcolunas dentro de 'Valor1'
    'AccuracyPredict1': [('Acuracia', 'mean'), ('Std', 'std')],  # Subcolunas dentro de 'Valor2'
    'AccuracyPredict2': [('Acuracia', 'mean'), ('Std', 'std')]  # Subcolunas dentro de 'Valor2'
     }).rename(columns={'ElipsedTimeTraining': 'Tempo Treinamento',
                   'ElipsedTimePredict1': 'Tempo Predict1',
                   'ElipsedTimePredict2': 'Tempo Predict2',
                   'AccuracyPredict1': 'Acuracia1',
                   'AccuracyPredict2': 'Acuracia2'
                   })

sumarizedGroup[('Tempo Treinamento', 'Mean')] = sumarizedGroup[('Tempo Treinamento', 'Mean')].map(lambda x: f"{x:.2f}")
sumarizedGroup[('Tempo Treinamento', 'Std')] = sumarizedGroup[('Tempo Treinamento', 'Std')].map(lambda x: f"{x:.2f}")
sumarizedGroup[('Tempo Predict1', 'Mean')] = sumarizedGroup[('Tempo Predict1', 'Mean')].map(lambda x: f"{x:.4f}")
sumarizedGroup[('Tempo Predict2', 'Mean')] = sumarizedGroup[('Tempo Predict2', 'Mean')].map(lambda x: f"{x:.4f}")
sumarizedGroup[('Acuracia1', 'Acuracia')] = sumarizedGroup[('Acuracia1', 'Acuracia')].map(lambda x: f"{x:.2f}")
sumarizedGroup[('Acuracia1', 'Std')] = sumarizedGroup[('Acuracia1', 'Std')].map(lambda x: f"{x:.2f}")
sumarizedGroup[('Acuracia2', 'Acuracia')] = sumarizedGroup[('Acuracia2', 'Acuracia')].map(lambda x: f"{x:.2f}")
sumarizedGroup[('Acuracia2', 'Std')] = sumarizedGroup[('Acuracia2', 'Std')].map(lambda x: f"{x:.2f}")


sumarizedGroup
# Out:
#                                         Tempo Treinamento        \
#                                                      Mean   Std
# DatabaseName             NumProcessUsed
# Iris                     4                           2.35  0.08
#                          8                           2.42  0.07
#                          16                          2.50  0.07
#                          32                          2.77  0.07
# ElectricalFaultDetection 4                          31.82  0.97
#                          8                          21.27  0.64
#                          16                         20.89  0.57
#                          32                         20.28  0.64
#
#                                         Tempo Predict1            \
#                                                   Mean       Std
# DatabaseName             NumProcessUsed
# Iris                     4                      0.0268  0.000337
# ...

# %%
df_tex = sumarizedGroup.to_latex(index=True, escape=False)
print(df_tex)
# Out:
# \begin{tabular}{lllllrlrllll}
# \toprule
#                          &    & \multicolumn{2}{l}{Tempo Treinamento} & \multicolumn{2}{l}{Tempo Predict1} & \multicolumn{2}{l}{Tempo Predict2} & \multicolumn{2}{l}{Acuracia1} & \multicolumn{2}{l}{Acuracia2} \\
#                          &    &              Mean &   Std &           Mean &       Std &           Mean &       Std &  Acuracia &   Std &  Acuracia &   Std \\
# DatabaseName & NumProcessUsed &                   &       &                &           &                &           &           &       &           &       \\
# \midrule
# Iris & 4  &              2.35 &  0.08 &         0.0268 &  0.000337 &         0.0224 &  0.000557 &     93.51 &  1.42 &     94.33 &  1.57 \\
#                          & 8  &              2.42 &  0.07 &         0.0277 &  0.000118 &         0.0224 &  0.000494 &     93.53 &  1.49 &     94.02 &  1.30 \\
# ...

# %%
sumarizedFlat = sumarizedGroup.reset_index()

onlyIris = sumarizedFlat['DatabaseName'] == 'Iris'
onlyElectricalFaultDetection = sumarizedFlat['DatabaseName'] == 'ElectricalFaultDetection'

sumarizedFlatIris = sumarizedFlat[onlyIris]
sumarizedFlatElectricalFaultDetection = sumarizedFlat[onlyElectricalFaultDetection]

# sumarizedGroupElectrical

# %%
#Dados comuns dos graficos
# procs = [1,4,8,16,32,48]
# processors = ['Serial','4 processos', '8 processos', '16 processos', '32 processos', '48 processos']
# bar_colors = ["#92C5F9", "#4394E5", "#0066CC", "#004D99", "#003366", "#001633"]

procs = [1,4,8,16,32]
processors = ['Serial','4 processos', '8 processos', '16 processos', '32 processos']
bar_colors = ["#92C5F9", "#4394E5", "#0066CC", "#004D99", "#003366"]

# procs = [1,16,24,32]
# processors = ['Serial', '16 processos', '24 processos', '32 processos']
# bar_colors = ["#92C5F9", "#4394E5", "#0066CC", "#004D99"]



serialTimeIris = 2.03
timesIris = pd.to_numeric(sumarizedFlatIris[('Tempo Treinamento','Mean')]).to_list()
#adding serial time execution from previous experiment
timesIris.insert(0, serialTimeIris)

speedupIris = np.divide(serialTimeIris,timesIris)
efficiencyIris = speedupIris/procs
differenceExecutionPercentIris = (1 - np.divide(timesIris,serialTimeIris)) * 100

dfResultIris = pd.DataFrame()
dfResultIris['procs'] = procs
dfResultIris['processors'] = processors
dfResultIris['speedup'] = speedupIris
dfResultIris['percent'] = differenceExecutionPercentIris
dfResultIris['efficiency'] = efficiencyIris


print(dfResultIris.to_latex())

fig, ax = plt.subplots(layout='constrained')
bar_container = ax.bar(processors, timesIris, label=processors, color=bar_colors)
ax.set(ylabel='Tempo (segundos)', ylim=(0, 5))
ax.bar_label(bar_container, fmt=lambda x: f'{x :.2f} (s)')
ax.legend(title='Qtd processos')

plt.show()
# Out:
# \begin{tabular}{lrlrrr}
# \toprule
# {} &  procs &    processors &   speedup &    percent &  efficiency \\
# \midrule
# 0 &      1 &        Serial &  1.000000 &   0.000000 &    1.000000 \\
# 1 &      4 &   4 processos &  0.863830 & -15.763547 &    0.215957 \\
# 2 &      8 &   8 processos &  0.838843 & -19.211823 &    0.104855 \\
# 3 &     16 &  16 processos &  0.812000 & -23.152709 &    0.050750 \\
# 4 &     32 &  32 processos &  0.732852 & -36.453202 &    0.022902 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_512908/1430534067.py:33: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(dfResultIris.to_latex())

# %%
serialTimeElectricalFaultDetection = 31.91
timesElectricalFaultDetection = pd.to_numeric(sumarizedFlatElectricalFaultDetection[('Tempo Treinamento','Mean')]).to_list()
#adding serial time execution from previous experiment
timesElectricalFaultDetection.insert(0, serialTimeElectricalFaultDetection)


#creating result dataframe
speedupElectricalFaultDetection = np.divide(serialTimeElectricalFaultDetection,timesElectricalFaultDetection)
efficiencyElectricalFaultDetection = speedupElectricalFaultDetection/procs
differenceExecutionPercentElectricalFaultDetection = (1 - np.divide(timesElectricalFaultDetection,serialTimeElectricalFaultDetection)) * 100

dfResultElectrical = pd.DataFrame()
dfResultElectrical['procs'] = procs
dfResultElectrical['processors'] = processors
dfResultElectrical['speedup'] = speedupElectricalFaultDetection
dfResultElectrical['percent'] = differenceExecutionPercentElectricalFaultDetection
dfResultElectrical['efficiency'] = efficiencyElectricalFaultDetection

print(dfResultElectrical.to_latex())


fig, ax = plt.subplots(layout='constrained')
bar_container = ax.bar(processors, timesElectricalFaultDetection,label=processors, color=bar_colors)
ax.set(ylabel='Tempo (segundos)', ylim=(0, 40))
ax.bar_label(bar_container, fmt=lambda x: f'{x :.2f} (s)')
ax.legend(title='Qtd processos')

plt.show()
# Out:
# \begin{tabular}{lrlrrr}
# \toprule
# {} &  procs &    processors &   speedup &    percent &  efficiency \\
# \midrule
# 0 &      1 &        Serial &  1.000000 &   0.000000 &    1.000000 \\
# 1 &      4 &   4 processos &  1.002828 &   0.282043 &    0.250707 \\
# 2 &      8 &   8 processos &  1.500235 &  33.343779 &    0.187529 \\
# 3 &     16 &  16 processos &  1.527525 &  34.534629 &    0.095470 \\
# 4 &     32 &  32 processos &  1.573471 &  36.446255 &    0.049171 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_512908/2258208707.py:19: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(dfResultElectrical.to_latex())
